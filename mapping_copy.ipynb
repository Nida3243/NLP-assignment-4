# %%
import os
import json
import pandas as pd
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
from src.encrypt import decrypt_data
from src.auth_helpers import get_access_token
from utils.chat_model import AIGatewayLangchainChatOpenAI

# Load configuration from JSON and environment
with open('secret/url.json', 'r') as file:
    url_data = json.load(file)
AI_GATEWAY_BASE_URL = url_data.get("ai_gateway")
issuer_url = url_data.get("issuer_url")

# Load the .env file from the specified directory
load_dotenv('secret/.env')  # Specify the full path to the .env file

# Retrieve and decrypt the environment variables
loaded_fernet_key = os.getenv('FERNET_KEY').encode()
loaded_encrypted_client_id = os.getenv('ENCRYPTED_CLIENT_ID').encode()
loaded_encrypted_client_secret = os.getenv('ENCRYPTED_CLIENT_SECRET').encode()

client_id = decrypt_data(loaded_encrypted_client_id, loaded_fernet_key)
client_secret = decrypt_data(loaded_encrypted_client_secret, loaded_fernet_key)

access_token = get_access_token(client_id, client_secret, issuer_url)

model = AIGatewayLangchainChatOpenAI(
    access_token=access_token, base_url=AI_GATEWAY_BASE_URL, model="o1-2024-12-17", deere_ai_gateway_registration_id="graphics-quality-check"
)

def invoke_model(data_frame, prompt):
    # Convert DataFrame to JSON string to send to the model
    data_json = data_frame.to_json(orient='records')
    message = HumanMessage(
        content=[
            {"type": "text", "text": prompt},
            {
                "type": "text",  # Change 'data' to 'text'
                "text": data_json,  # Include the JSON string in the message
            },
        ],
    )
    response = model.invoke([message])
    return response.content

def read_excel_file(file_path, sheet_name=None):
    try:
        # Read the specified sheet into a DataFrame
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        return df
    except Exception as e:
        print(f"Failed to read Excel file: {e}")
        return None

def process_excel_with_prompt(file_path, sheet_name, requirements):
    df = read_excel_file(file_path, sheet_name)
    if df is None:
        return "Excel file reading failed."
    
    results = {}
    
    # Assuming that the only relevant column is "Anchor Text"
    anchor_text_column = "Anchor Text"  # Ensure this matches your sheet
    #requirements_column= "Requirement"

    # Constructing the prompt with the provided requirements
    prompt = f'''You are an expert in creating schematic legends and specializing in data mapping.

you will find a column named {requirements_input} that contains alphanumeric characters or values for which we need to find legend details in the code.

And in the sheet you will find The column {anchor_text_column} contains alphanumeric characters along with their full forms or legend values, which we will use for mapping.

Your task is to extract all entries from the {anchor_text_column} that match any of the requirements listed in the {requirements_input}. Please provide the entire content of any matching cells.

For example, if the requirement is "A046", you should search for "A046" in the {anchor_text_column}. If found, return all related entries, such as:

0A046—Drive Train Domain Control Unit (5-V Output) Circuit Test
A046—Drive Train Domain Control Unit (12-V Supply) Circuit Test
A046—Drive Train Domain Control Unit Electrical Schematic (12-V Supply)
A046—Drive Train Domain Control Unit Electrical Schematic (5-V Output)
A046—Drive Train Domain Control Unit
X870-8—Power Supply for Drive Train and Transmission Control Unit (A046, A062, A065)
These are the mappings for "A046" obtained from the {anchor_text_column} column.

Note: It is possible that not all requirements will have matching entries in the {anchor_text_column}.
Format everything as HTML that can be used in a website. 
Place the description in a <div> element.
'''

    # Invoke the model with the prompt and data from the DataFrame
    result = invoke_model(df, prompt)
    results[sheet_name] = result
    
    return results

# Example usage
excel_file_path = r"""C:\Users\W4FGXUV\Downloads\Legend_creation\extracted_anchors.xlsx"""  # Update with your actual file path
sheet_name = "Sheet1"  # Specify your sheet name here

# Input field for requirements
requirements_input = """A046
A047
A136
Alternator
B028-1
B028-2
Battery
Battery Cut-Off Relay
Cab Switch 
Circuit 
Diode PLBU
Drive Train Domain CAN Bus
Drive Train Domain Control Unit
F103
G001
G001-2
G004
Ground Point
Ground Point (Cab)
Ground Point (Roof)
Hydraulic and Options Domain CAN Bus"""

# Split the input into a list
requirements = [req.strip() for req in requirements_input.splitlines() if req.strip()]

# Process the Excel file with the provided requirements
results = process_excel_with_prompt(excel_file_path, sheet_name, requirements)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       6 from src.encrypt import decrypt_data
#       7 from src.auth_helpers import get_access_token
# ----> 8 from utils.chat_model import AIGatewayLangchainChatOpenAI
#      10 # Load configuration from JSON and environment
#      11 with open('secret/url.json', 'r') as file:
#
# File c:\Users\W4FGXUV\Downloads\Graphics_Quality_Check\Graphics_Quality_Check\utils\chat_model.py:6
#       4 import httpx
#       5 import json
# ----> 6 from langchain_openai.chat_models import ChatOpenAI
#       7 from typing import Optional
#       9 class AIGatewayLangchainChatOpenAI(ChatOpenAI):
#
# ModuleNotFoundError: No module named 'langchain_openai'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from IPython.display import display, HTML

# Assuming `results` contains the HTML content
html_content = results['Sheet1']  # Extract the HTML string from your results

# Display the HTML content
display(HTML(html_content))
# Out:
# <html>
# <head>
#     <meta charset="utf-8" />
#     <title>Matched Requirements</title>
# </head>
# <body>
# <div>
#
#     <!--
#          Below are all matches found where the "Requirement" field
#          matches any of the following:
#          A046, A047, A136, Alternator, B028-1, B028-2, Battery,
#          Battery Cut-Off Relay, Cab Switch, Circuit, Diode PLBU,
#          Drive Train Domain CAN Bus, Drive Train Domain Control Unit,
#          F103, G001, G001-2, G004, Ground Point, Ground Point (Cab),
#          Ground Point (Roof), Hydraulic and Options Domain CAN Bus.
#     -->
#
#     <!-- 1. Matches for A046 -->
#     <h2>A046</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-e5d749be-9924-4db2-c0eb-ffc002364cdd</p>
#         <p><strong>SGML ID:</strong> id-93d12013-e879-4392-82f7-56a1f007aa96</p>
#         <p><strong>Anchor Text:</strong> Work In Ventilated
# Area</p>
#         <p><strong>Requirement:</strong> A046</p>
#     </div>
#
#     <!-- 2. Matches for A047 -->
#     <h2>A047</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-1c8b2311-bac4-4b26-aee9-ed710bcd7194</p>
#         <p><strong>SGML ID:</strong> id-03df14a1-8fc3-4c0b-d088-b6d0b007575a</p>
#         <p><strong>Anchor Text:</strong> Recognize Safety
# Information</p>
#         <p><strong>Requirement:</strong> A047</p>
#     </div>
#
#     <!-- 3. Matches for A136 -->
#     <h2>A136</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-63810192-c923-4dac-e08c-6a1bacb69aa7</p>
#         <p><strong>SGML ID:</strong> id-2436ebdb-c60c-4bc4-ca2d-0a7ae2d9f2d4</p>
#         <p><strong>Anchor Text:</strong> Avoid Backover Accidents</p>
#         <p><strong>Requirement:</strong> A136</p>
#     </div>
#
#     <!-- 4. Matches for Alternator -->
#     <h2>Alternator</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-cadca58a-17fc-42b5-ffd6-8d807a244b1c</p>
#         <p><strong>SGML ID:</strong> id-9ec16146-a9ae-40e5-9282-c9faa43a71ca</p>
#         <p><strong>Anchor Text:</strong> Prevent Machine Runaway</p>
#         <p><strong>Requirement:</strong> Alternator</p>
#     </div>
#
#     <!-- 5. Matches for B028-1 -->
#     <h2>B028-1</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-a4dfd5f9-e8fe-4217-edd8-2fa278dd3ed0</p>
#         <p><strong>SGML ID:</strong> id-5832fe8b-368a-498f-b836-ac8144d8d7a6</p>
#         <p><strong>Anchor Text:</strong> Avoid Contact with
# Agricultural Chemicals</p>
#         <p><strong>Requirement:</strong> B028-1</p>
#     </div>
#
#     <!-- 6. Matches for B028-2 -->
#     <h2>B028-2</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-47d6577a-eda3-4f60-dd1b-e17ccb7f1f8b</p>
#         <p><strong>SGML ID:</strong> id-ad0324fc-cbea-4f98-a99c-4faaacd937a3</p>
#         <p><strong>Anchor Text:</strong> Work in Clean Area</p>
#         <p><strong>Requirement:</strong> B028-2</p>
#     </div>
#
#     <!-- 7. Matches for Battery -->
#     <h2>Battery</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-483da271-4653-4ac0-db54-5608f7ffe7d4</p>
#         <p><strong>SGML ID:</strong> id-dbc37c1f-e744-44c8-9ea2-b34636972e78</p>
#         <p><strong>Anchor Text:</strong> Decommissioning —
# Proper Recycling and Disposal of Fluids and Components</p>
#         <p><strong>Requirement:</strong> Battery</p>
#     </div>
#
#     <!-- 8. Matches for Battery Cut-Off Relay -->
#     <h2>Battery Cut-Off Relay</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-a30709c7-3b87-486d-e7eb-7acbf919121b</p>
#         <p><strong>SGML ID:</strong> id-1c8e27d2-ca8f-4701-cf22-5e0aa6a711ce</p>
#         <p><strong>Anchor Text:</strong> Avoid Hot Exhaust</p>
#         <p><strong>Requirement:</strong> Battery Cut-Off Relay</p>
#     </div>
#
#     <!-- 9. Matches for Cab Switch -->
#     <h2>Cab Switch</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-160ed991-a0d6-40d3-c527-7ee4343d1b37</p>
#         <p><strong>SGML ID:</strong> id-3ef6166d-4b5f-41c9-a736-8756c63e00ae</p>
#         <p><strong>Anchor Text:</strong> Clean Exhaust Filter
# Safely</p>
#         <p><strong>Requirement:</strong> Cab Switch </p>
#     </div>
#
#     <!-- 10. Matches for Circuit -->
#     <h2>Circuit</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-09043427-7adc-49c3-ea73-a8fb92cb8050</p>
#         <p><strong>SGML ID:</strong> id-290d01d1-2c26-44a3-9fbe-7cd75deb1720</p>
#         <p><strong>Anchor Text:</strong> Exhaust Filter Cleaning</p>
#         <p><strong>Requirement:</strong> Circuit </p>
#     </div>
#
#     <!-- 11. Matches for Diode PLBU -->
#     <h2>Diode PLBU</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-332ff8e3-85d8-4db1-dd2d-5ac6dce8a76c</p>
#         <p><strong>SGML ID:</strong> id-0c7f61e8-5f4a-43c2-c17f-f41ba157b4a0</p>
#         <p><strong>Anchor Text:</strong> Prepare for Emergencies</p>
#         <p><strong>Requirement:</strong> Diode PLBU</p>
#     </div>
#
#     <!-- 12. Matches for Drive Train Domain CAN Bus -->
#     <h2>Drive Train Domain CAN Bus</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-e732cd5c-425a-4b6e-ecee-d2d70ef29d63</p>
#         <p><strong>SGML ID:</strong> id-2c8974fa-d8ed-4105-b5e0-f22e2a169a63</p>
#         <p><strong>Anchor Text:</strong> Handle Fluids Safely—Avoid
# Fires</p>
#         <p><strong>Requirement:</strong> Drive Train Domain CAN Bus</p>
#     </div>
#
#     <!-- 13. Matches for Drive Train Domain Control Unit -->
#     <h2>Drive Train Domain Control Unit</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-9cf39a85-127a-4dfa-c72f-92db5043cf6c</p>
#         <p><strong>SGML ID:</strong> id-af6929b4-ae57-4818-ac08-f6d60fa13cc9</p>
#         <p><strong>Anchor Text:</strong> Use Safety Lights
# and Devices</p>
#         <p><strong>Requirement:</strong> Drive Train Domain Control Unit</p>
#     </div>
#
#     <!-- 14. Matches for F103 -->
#     <h2>F103</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-4d687667-5f50-4cd4-8d64-f4f4634beecb</p>
#         <p><strong>SGML ID:</strong> id-417fc041-37fb-4b75-cf37-164bf3b652d0</p>
#         <p><strong>Anchor Text:</strong> Avoid High-Pressure
# Fluids</p>
#         <p><strong>Requirement:</strong> F103</p>
#     </div>
#
#     <!-- 15. Matches for G001 -->
#     <h2>G001</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-fdc2d630-2454-4c04-d1d5-0283fa1efbb6</p>
#         <p><strong>SGML ID:</strong> id-5574a0f7-787f-47a1-c9a2-b519adcb7646</p>
#         <p><strong>Anchor Text:</strong> Use Proper Lifting
# Equipment</p>
#         <p><strong>Requirement:</strong> G001</p>
#     </div>
#
#     <!-- 16. Matches for G001-2 -->
#     <h2>G001-2</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-09689e05-dc4f-4f3a-ecdc-c7129fdacd13</p>
#         <p><strong>SGML ID:</strong> id-9229fe03-5945-4beb-966e-71e7ecb39d03</p>
#         <p><strong>Anchor Text:</strong> Illuminate Work Area
# Safely</p>
#         <p><strong>Requirement:</strong> G001-2</p>
#     </div>
#
#     <!-- 17. Matches for G004 -->
#     <h2>G004</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-f15b5905-e1aa-4395-9eb8-de7af1148bf4</p>
#         <p><strong>SGML ID:</strong> id-283ecb97-ed58-4439-e8f4-6003dda65344</p>
#         <p><strong>Anchor Text:</strong> Live With Safety</p>
#         <p><strong>Requirement:</strong> G004</p>
#     </div>
#
#     <!-- 18. Matches for Ground Point -->
#     <h2>Ground Point</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-77a245b1-6c4a-4367-d110-720e14d4a687</p>
#         <p><strong>SGML ID:</strong> id-bd0b65ed-40bd-4957-ed1f-26d938526cae</p>
#         <p><strong>Anchor Text:</strong> Service Machines
# Safely</p>
#         <p><strong>Requirement:</strong> Ground Point</p>
#     </div>
#
#     <!-- 19. Matches for Ground Point (Cab) -->
#     <h2>Ground Point (Cab)</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-629e46b0-96c7-4300-be09-210a183e0425</p>
#         <p><strong>SGML ID:</strong> id-ecc41c1d-11f8-4ec0-b998-65c59a12c056</p>
#         <p><strong>Anchor Text:</strong> Support Machine Properly</p>
#         <p><strong>Requirement:</strong> Ground Point (Cab)</p>
#     </div>
#
#     <!-- 20. Matches for Ground Point (Roof) -->
#     <h2>Ground Point (Roof)</h2>
#     <div>
#         <p><strong>Ref ID:</strong> id-9c386879-1890-4a0c-8d40-bdaf103d164f</p>
#         <p><strong>SGML ID:</strong> id-40968816-e00d-41d3-be04-22f7539d16fc</p>
#         <p><stro

# %%
import os
import json
import pandas as pd
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
from src.encrypt import decrypt_data
from src.auth_helpers import get_access_token
from utils.chat_model import AIGatewayLangchainChatOpenAI

# Load configuration from JSON and environment
with open('secret/url.json', 'r') as file:
    url_data = json.load(file)
AI_GATEWAY_BASE_URL = url_data.get("ai_gateway")
issuer_url = url_data.get("issuer_url")

# Load the .env file from the specified directory
load_dotenv('secret/.env')  # Specify the full path to the .env file

# Retrieve and decrypt the environment variables
loaded_fernet_key = os.getenv('FERNET_KEY').encode()
loaded_encrypted_client_id = os.getenv('ENCRYPTED_CLIENT_ID').encode()
loaded_encrypted_client_secret = os.getenv('ENCRYPTED_CLIENT_SECRET').encode()

client_id = decrypt_data(loaded_encrypted_client_id, loaded_fernet_key)
client_secret = decrypt_data(loaded_encrypted_client_secret, loaded_fernet_key)

access_token = get_access_token(client_id, client_secret, issuer_url)

model = AIGatewayLangchainChatOpenAI(
    access_token=access_token, base_url=AI_GATEWAY_BASE_URL, model="o1-2024-12-17", deere_ai_gateway_registration_id="graphics-quality-check"
)

def invoke_model(data_frame, prompt):
    # Convert DataFrame to JSON string to send to the model
    data_json = data_frame.to_json(orient='records')
    message = HumanMessage(
        content=[
            {"type": "text", "text": prompt},
            {
                "type": "text",  # Change 'data' to 'text'
                "text": data_json,  # Include the JSON string in the message
            },
        ],
    )
    response = model.invoke([message])
    return response.content

def read_excel_file(file_path, sheet_name=None):
    try:
        # Read the specified sheet into a DataFrame
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        return df
    except Exception as e:
        print(f"Failed to read Excel file: {e}")
        return None

def process_excel_with_prompt(file_path, sheet_name, requirements):
    df = read_excel_file(file_path, sheet_name)
    if df is None:
        return "Excel file reading failed."
    
    results = {}
    
    # Assuming that the only relevant column is "Anchor Text"
    anchor_text_column = "Anchor Text"  # Ensure this matches your sheet
    #requirements_column= "Requirement"

    # Constructing the prompt with the provided requirements
    prompt = f'''You are an expert in creating schematic legends and specializing in data mapping.

You will find a column named {requirements_input} that contains alphanumeric characters or values for which we need to find legend details in the code.

In the sheet, you will find that the column {anchor_text_column} contains alphanumeric characters along with their full forms or legend values, which we will use for mapping.

Your task is to extract all entries from the {anchor_text_column} that match any of the requirements listed in {requirements_input}. Please provide the entire content of any matching cells.

Note: It is possible that not all requirements will have matching entries in the {anchor_text_column}.

Format everything as HTML that can be used in a website. Place the description in a <div> element..
'''

    # Invoke the model with the prompt and data from the DataFrame
    result = invoke_model(df, prompt)
    results[sheet_name] = result
    
    return results

# Example usage
excel_file_path = r"""C:\Users\W4FGXUV\Downloads\Legend_creation\extracted_anchors.xlsx"""  # Update with your actual file path
sheet_name = "Sheet1"  # Specify your sheet name here

# Input field for requirements
requirements_input = """A046
A047
A136
Alternator
B028-1
B028-2
Battery
Battery Cut-Off Relay
Cab Switch 
Circuit 
Diode PLBU
Drive Train Domain CAN Bus
Drive Train Domain Control Unit
F103
G001
G001-2
G004
Ground Point
Ground Point (Cab)
Ground Point (Roof)
Hydraulic and Options Domain CAN Bus"""

# Split the input into a list
requirements = [req.strip() for req in requirements_input.splitlines() if req.strip()]

# Process the Excel file with the provided requirements
results = process_excel_with_prompt(excel_file_path, sheet_name, requirements)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       6 from src.encrypt import decrypt_data
#       7 from src.auth_helpers import get_access_token
# ----> 8 from utils.chat_model import AIGatewayLangchainChatOpenAI
#      10 # Load configuration from JSON and environment
#      11 with open('secret/url.json', 'r') as file:
#
# File c:\Users\W4FGXUV\Downloads\Graphics_Quality_Check\Graphics_Quality_Check\utils\chat_model.py:6
#       4 import httpx
#       5 import json
# ----> 6 from langchain_openai.chat_models import ChatOpenAI
#       7 from typing import Optional
#       9 class AIGatewayLangchainChatOpenAI(ChatOpenAI):
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (0.3.22)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (0.3.49)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (0.3.22)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (2.11.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: requests<3,>=2 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (2.32.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\w4fgxuv\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain) (4.13.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain) (2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\w4fgxuv\appdata\local\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
